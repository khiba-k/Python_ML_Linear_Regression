# %% [markdown]
# <a href="https://colab.research.google.com/github/khiba-k/Python_ML_Linear_Regression/blob/main/position_vs_salary_polynomial_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv("Position_Salaries.csv")
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
regressor = LinearRegression()
regressor.fit(X, y)
predicted_y = regressor.predict(X)

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
poly_reg = PolynomialFeatures(degree=4)
X_poly = poly_reg.fit_transform(X)
regressor2 = LinearRegression()
regressor2.fit(X_poly, y)
predicted_y_poly = regressor2.predict(X_poly)

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(X, y, color='red')
plt.plot(X, predicted_y, color='blue')
plt.title("Position vs Salary Graph(Simple Linear Regression)")
plt.xlabel("Position")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
plt.scatter(X, y, color="red")
plt.plot(X, predicted_y_poly, color="blue")
plt.title("Position vs Salary (Polynomial Regression)")
plt.xlabel("Position")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results (for higher resolution and smoother curve)

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
regressor.predict([[6.5]])
# Out:
# array([330378.78787879])

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
regressor2.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([158862.45265155])
